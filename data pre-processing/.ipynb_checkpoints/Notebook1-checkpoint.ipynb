# %% [markdown]
#  Step - 1: Importing Libraries and Loading Dataset

# %%
# Importing all the necessary packages and libraries

import numpy as np # linear algebra
import pandas as pd # Data pre-processing
import seaborn as sns # Required for plotting
import matplotlib.pyplot as plt # Required for plotting

# %%
spotify = pd.read_csv("../dataset/songs_updated_v2.csv") # Using pandas lib to read table
spotify.head() # Checking data schema for validation purpose
# Out:
#            artist                    song  duration_ms  explicit  year  \
# 0  Britney Spears  Oops!...I Did It Again       211160     False  2000
# 1       blink-182    All The Small Things       167066     False  1999
# 2      Faith Hill                 Breathe       250546     False  1999
# 3        Bon Jovi            It's My Life       224493     False  2000
# 4          *NSYNC             Bye Bye Bye       200560     False  2000
#
#    popularity  danceability  energy  key  loudness  ...    pop  folk_acoustic  \
# 0          77         0.751   0.834    1    -5.444  ...   True          False
# 1          79         0.434   0.897    0    -4.918  ...   True          False
# 2          66         0.529   0.496    7    -9.007  ...   True          False
# 3          78         0.551   0.913    0    -4.063  ...  False          False
# 4          65         0.614   0.928    8    -4.806  ...   True          False
#
#    dance_electronic    r&b  classical  blues  latin easy_listening  country  \
# 0             False  False      False  False  False          False    False
# 1             False  False      False  False  False          False    False
# 2             False  False      False  False  False          False     True
# 3             False  False      False  False  False          False    False
# 4             False  False      False  False  False          False    False
#
#    hasFeature
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#
# [5 rows x 33 columns]

# %% [markdown]
# Step - 2: Identifying Missing values

# %%
spotify.info() # Checking presence of any null values in columns
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 33 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   artist             2000 non-null   object
#  1   song               2000 non-null   object
#  2   duration_ms        2000 non-null   int64
#  3   explicit           2000 non-null   bool
#  4   year               2000 non-null   int64
#  5   popularity         2000 non-null   int64
#  6   danceability       2000 non-null   float64
#  7   energy             2000 non-null   float64
#  8   key                2000 non-null   int64
#  9   loudness           2000 non-null   float64
#  10  mode               2000 non-null   int64
#  11  speechiness        2000 non-null   float64
#  12  acousticness       2000 non-null   float64
#  13  instrumentalness   2000 non-null   float64
#  14  liveness           2000 non-null   float64
#  15  valence            2000 non-null   float64
#  16  tempo              2000 non-null   float64
#  17  genre              2000 non-null   object
#  18  world_traditional  2000 non-null   bool
#  19  jazz               2000 non-null   bool
#  20  hip_hop            2000 non-null   bool
#  21  metal              2000 non-null   bool
#  22  rock               2000 non-null   bool
#  23  pop                2000 non-null   bool
#  24  folk_acoustic      2000 non-null   bool
#  25  dance_electronic   2000 non-null   bool
#  26  r&b                2000 non-null   bool
#  27  classical          2000 non-null   bool
#  28  blues              2000 non-null   bool
#  29  latin              2000 non-null   bool
#  30  easy_listening     2000 non-null   bool
#  31  country            2000 non-null   bool
#  32  hasFeature         2000 non-null   bool
# dtypes: bool(16), float64(9), int64(5), object(3)
# memory usage: 297.0+ KB

# %% [markdown]
# Check for any duplicates

# %%
dp_rows = spotify[spotify.duplicated()]
print("Number of duplicated rows: ",len(dp_rows))
# Out:
# Number of duplicated rows:  59

# %% [markdown]
# There are no nulls but there are duplicates which needs to be removed

# %% [markdown]
# Step 3- Remove Duplicates

# %%
# Cloning spotify data table for avoiding any tampering
spotify_clone1 = spotify

# Removed duplicates to negate any bias
spotify_unique = spotify_clone1.drop_duplicates()
spotify_unique
# Out:
#               artist                                    song  duration_ms  \
# 0     Britney Spears                  Oops!...I Did It Again       211160
# 1          blink-182                    All The Small Things       167066
# 2         Faith Hill                                 Breathe       250546
# 3           Bon Jovi                            It's My Life       224493
# 4             *NSYNC                             Bye Bye Bye       200560
# ...              ...                                     ...          ...
# 1995  Jonas Brothers                                  Sucker       181026
# 1996    Taylor Swift                            Cruel Summer       178426
# 1997    Blanco Brown                              The Git Up       200593
# 1998       Sam Smith  Dancing With A Stranger (with Normani)       171029
# 1999     Post Malone                                 Circles       215280
#
#       explicit  year  popularity  danceability  energy  key  loudness  ...  \
# 0        False  2000          77         0.751   0.834    1    -5.444  ...
# 1        False  1999          79         0.434   0.897    0    -4.918  ...
# 2        False  1999          66         0.529   0.496    7    -9.007  ...
# 3        False  2000          78         0.551   0.913    0    -4.063  ...
# 4        False  2000          65         0.614   0.928    8    -4.806  ...
# ...        ...   ...         ...           ...     ...  ...       ...  ...
# 1995     False  2019          79         0.842   0.734    1    -5.065  ...
# 1996     False  2019          78         0.552   0.702    9    -5.707  ...
# 1997     False  2019          69         0.847   0.678    9    -8.635  ...
# 1998     False  2019          75         0.741   0.520    8    -7.513  ...
# 1999     False  2019          85         0.695   0.762    0    -3.497  ...
#
#         pop  folk_acoustic  dance_electronic    r&b  classical  blues  latin  \
# 0      True          False             False  False      False  False  False
# 1      True          False             False  False      False  False  False
# 2      True          False             False  False      False  False  False
# 3     False          False             False  False      False  False  False
# 4      True          False             False  False      False  False  False
# ...     ...            ...               ...    ...        ...    ...    ...
# 1995   True          False             False  False      False  False  False
# 1996   True          False             False  False      False  False  False
# 1997  False          False             False  False      False  False  False
# 1998   True          False             False  False      False  False  False
# 1999  False          False             False  False      False  False  False
#
#      easy_listening  country  hasFeature
# 0             False    False       False
# 1             False    False       False
# 2             False     True       False
# 3             False    False       False
# 4             False    False       False
# ...             ...      ...         ...
# 1995          False    False       False
# 1996          False    False       False
# 1997          False     True       False
# 1998          False    False        True
# 1999          False    False       False
#
# [1941 rows x 33 columns]

# %% [markdown]
# We can see that there were 59 duplicates (1941+59=2000)

# %% [markdown]
# 1. How many songs released in which year?

# %%
year_distr = spotify_clone1.groupby("year").size().sort_values(ascending=False).reset_index(name='count') 
year_distr
# Out:
#     year  count
# 0   2012    115
# 1   2017    111
# 2   2001    108
# 3   2018    107
# 4   2010    107
# 5   2014    104
# 6   2005    104
# 7   2016     99
# 8   2015     99
# 9   2011     99
# 10  2008     97
# 11  2003     97
# 12  2004     96
# 13  2006     95
# 14  2007     94
# 15  2002     90
# 16  2019     89
# 17  2013     89
# 18  2009     84
# 19  2000     74
# 20  1999     38
# 21  2020      3
# 22  1998      1

# %% [markdown]
# 2. How many songs belong to each genre

# %%
genre_distr = spotify_clone1.groupby("genre").size().sort_values(ascending=False).reset_index(name='count') 
genre_distr
# Out:
#                                     genre  count
# 0                                     pop    428
# 1                            hip hop, pop    277
# 2                       hip hop, pop, R&B    244
# 3                   pop, Dance/Electronic    221
# 4                                pop, R&B    178
# 5                                 hip hop    124
# 6          hip hop, pop, Dance/Electronic     78
# 7                                    rock     58
# 8                               rock, pop     43
# 9                        Dance/Electronic     41
# 10                            rock, metal     38
# 11                             pop, latin     28
# 12                              pop, rock     26
# 13                                  set()     22
# 14              hip hop, Dance/Electronic     16
# 15                                  latin     15
# 16                    hip hop, pop, latin     14
# 17                       pop, rock, metal     14
# 18                                    R&B     13
# 19            pop, rock, Dance/Electronic     13
# 20                                country     10
# 21                                  metal      9
# 22                     hip hop, pop, rock      9
# 23            rock, pop, Dance/Electronic      8
# 24                     pop, Folk/Acoustic      8
# 25                           pop, country      8
# 26             pop, R&B, Dance/Electronic      6
# 27                       rock, pop, metal      4
# 28                           hip hop, R&B      3
# 29               hip hop, pop, R&B, latin      3
# 30    hip hop, pop, R&B, Dance/Electronic      3
# 31               pop, rock, Folk/Acoustic      2
# 32                     rock, blues, latin      2
# 33                     hip hop, rock, pop      2
# 34             World/Traditional, hip hop      2
# 35              pop, easy listening, jazz      2
# 36           World/Traditional, rock, pop      2
# 37  World/Traditional, pop, Folk/Acoustic      2
# 38                World/Traditional, rock      2
# 39                     Folk/Acoustic, pop      2
# 40                            rock, blues      2
# 41          rock, R&B, Folk/Acoustic, pop      1
# 42     rock, pop, metal, Dance/Electronic      1
# 43                    Folk/Acoustic, rock      1
# 44               Folk/Acoustic, rock, pop      1
# 45                   rock, easy listening      1
# 46                        rock, classical      1
# 47                  hip hop, pop, country      1
# 48               rock, Folk/Acoustic, pop      1
# 49    rock, Folk/Acoustic, easy listening      1
# 50                 rock, Dance/Electronic      1
# 51                       hip hop, country      1
# 52       hip hop, latin, Dance/Electronic      1
# 53                         country, latin      1
# 54       World/Traditional, Folk/Acoustic      1
# 55  pop, easy listening, Dance/Electronic      1
# 56               pop, R&B, easy listening      1
# 57                 World/Traditional, pop      1
# 58                         easy listening      1

# %% [markdown]
# Observed a value in genre called set() having 22 records. It seems invalid input in the category of genre. It may give wrong interpretation in the genre distribution. Hence it should be removed.

# %%
spotify_unique = spotify_unique.query("genre != 'set()'")
spotify_unique
# Out:
#               artist                                    song  duration_ms  \
# 0     Britney Spears                  Oops!...I Did It Again       211160
# 1          blink-182                    All The Small Things       167066
# 2         Faith Hill                                 Breathe       250546
# 3           Bon Jovi                            It's My Life       224493
# 4             *NSYNC                             Bye Bye Bye       200560
# ...              ...                                     ...          ...
# 1995  Jonas Brothers                                  Sucker       181026
# 1996    Taylor Swift                            Cruel Summer       178426
# 1997    Blanco Brown                              The Git Up       200593
# 1998       Sam Smith  Dancing With A Stranger (with Normani)       171029
# 1999     Post Malone                                 Circles       215280
#
#       explicit  year  popularity  danceability  energy  key  loudness  ...  \
# 0        False  2000          77         0.751   0.834    1    -5.444  ...
# 1        False  1999          79         0.434   0.897    0    -4.918  ...
# 2        False  1999          66         0.529   0.496    7    -9.007  ...
# 3        False  2000          78         0.551   0.913    0    -4.063  ...
# 4        False  2000          65         0.614   0.928    8    -4.806  ...
# ...        ...   ...         ...           ...     ...  ...       ...  ...
# 1995     False  2019          79         0.842   0.734    1    -5.065  ...
# 1996     False  2019          78         0.552   0.702    9    -5.707  ...
# 1997     False  2019          69         0.847   0.678    9    -8.635  ...
# 1998     False  2019          75         0.741   0.520    8    -7.513  ...
# 1999     False  2019          85         0.695   0.762    0    -3.497  ...
#
#         pop  folk_acoustic  dance_electronic    r&b  classical  blues  latin  \
# 0      True          False             False  False      False  False  False
# 1      True          False             False  False      False  False  False
# 2      True          False             False  False      False  False  False
# 3     False          False             False  False      False  False  False
# 4      True          False             False  False      False  False  False
# ...     ...            ...               ...    ...        ...    ...    ...
# 1995   True          False             False  False      False  False  False
# 1996   True          False             False  False      False  False  False
# 1997  False          False             False  False      False  False  False
# 1998   True          False             False  False      False  False  False
# 1999  False          False             False  False      False  False  False
#
#      easy_listening  country  hasFeature
# 0             False    False       False
# 1             False    False       False
# 2             False     True       False
# 3             False    False       False
# 4             False    False       False
# ...             ...      ...         ...
# 1995          False    False       False
# 1996          False    False       False
# 1997          False     True       False
# 1998          False    False        True
# 1999          False    False       False
#
# [1919 rows x 33 columns]

# %%
# Write updated data frame to CSV
spotify_unique.to_csv('../dataset/songs_updated_v3.csv', index=False)

# %% [markdown]
# Data Pre-Precessing is completed
